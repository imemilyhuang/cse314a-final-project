# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import openai
print(openai.__version__)
import json
# Out:
# 1.76.0

# %%
# insert openai api key here -- can't push to github with this
client = openai.OpenAI(api_key="[INSERT OPEN API KEY]")

# %%
def detect_red_flags_and_weights(text):
    if pd.isna(text) or not text.strip():
        return {}

    prompt = (
        "Identify any red‐flag concerns for job candidates in the following text. "
        "For each one, give a severity score from 1 (minor) to 5 (major). "
        "Return *only* a JSON object where keys are the red‐flag phrase and values are the score.\n\n"
        f"Text: {text}"
    )

    resp = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system",  "content": "You are a concise assistant."},
            {"role": "user",    "content": prompt}
        ]
    )

    # extract the raw reply
    raw = resp.choices[0].message.content.strip()

    # try to parse valid JSON; if GPT slipped in markdown, strip it
    try:
        # sometimes GPT wraps JSON in ```json ...```
        json_part = raw
        if raw.startswith("```"):
            json_part = raw.split("```")[1]
        return json.loads(json_part)
    except json.JSONDecodeError:
        # fallback: empty dict
        return {}

# %%
df_companies = pd.read_csv("../test normalization/export_companies_copy.csv")
df_companies.head()
# Out:
#           normalized_slug              company_name  \
# 0               1password                 1Password
# 1                 7shifts                   7shifts
# 2  acadianassetmanagement  Acadian Asset Management
# 3                  appian                    Appian
# 4                   apple                     Apple
#
#                                          description  \
# 0  A password manager, digital vault, form filler...
# 1  Restaurant Employee Scheduling Software. Make ...
# 2                                                NaN
# 3  The company sells a Platform as a Service for ...
# 4  Apple Inc. is an American multinational techno...
#
#                                             overview  \
# 0  1Password provides a password management and s...
# 1  7shifts is a workforce management platform tai...
# 2  Acadian Asset Management specializes in invest...
# 3      Company Historically Provides H1B Sponsorship
# 4  Apple Inc. designs, manufactures, and sells a ...
#
#                                              website  \
# 0  https://1password.com/?ref=levels.fyi&utm_sour...
# 1  https://www.7shifts.com/?ref=levels.fyi&utm_so...
# 2                                                NaN
# 3  https://www.appian.com/?ref=levels.fyi&utm_sou...
# 4  https://www.apple.com/?ref=levels.fyi&utm_sour...
#
#                          twitter  \
# 0  https://twitter.com/1Password
# 1    https://twitter.com/7shifts
# 2                            NaN
# 3     https://twitter.com/Appian
# 4      https://twitter.com/Apple
#
#                                             linkedin  year_founded  \
# 0         https://www.linkedin.com/company/1password        2005.0
# 1           https://www.linkedin.com/company/7shifts        2014.0
# 2                                                NaN           NaN
# 3  https://www.linkedin.com/company/appian-corpor...        1999.0
# 4             https://www.linkedin.com/company/apple        1976.0
#
#    founded_year num_employees  ... company_stage total_funding  \
# 0          2005           420  ...      Series C         $920M
# 1          2014           290  ...      Series C         $131M
# 2          1986           NaN  ...           NaN           NaN
# 3          1999         2,000  ...           IPO         $123M
# 4          1976       147,000  ...           IPO      $6250.9M
#
#                                        simplify_url  \
# 0                 https://simplify.jobs/c/1Password
# 1                   https://simplify.jobs/c/7shifts
# 2  https://simplify.jobs/c/Acadian-Asset-Management
# 3                    https://simplify.jobs/c/Appian
# 4                     https://simplify.jobs/c/Apple
#
#                                        simplify_take  \
# 0  What believers are saying Growing demand for s...
# 1  What believers are saying 7shifts ranked 382 o...
# 2  What believers are saying Increased interest i...
# 3  What believers are saying Growing demand for l...
# 4  What believers are saying Apple's AR glasses d...
#
#                                      believer_points  \
# 0  Growing demand for secure access solutions due...
# 1  7shifts ranked 382 on the 2024 Deloitte Techno...
# 2  Increased interest in ESG investing aligns wit...
# 3  Growing demand for low-code platforms boosts A...
# 4  Apple's AR glasses development could capture m...
#
#                                        critic_points  \
# 0  Emerging competitors offer similar features at...
# 1  19% staff reduction may impact 7shifts' servic...
# 2  Competition from firms like Two Sigma may erod...
# 3  Unfavorable legal rulings could harm Appian's ...
# 4  Developing AR glasses may lead to high R&D cos...
#
#                                    what_makes_unique  \
# 0  1Password integrates seamlessly with IAM syste...
# 1  7shifts offers a comprehensive platform tailor...
# 2  Acadian uses sophisticated analytical models f...
# 3  Appian's low-code platform enables rapid appli...
# 4  Apple's integrated hardware and software creat...
#
#                                             benefits  \
# 0  👶 Maternity and parental leave top up programs...
# 1  Health Insurance\nCompany Equity\nFlexible Wor...
# 2  Hybrid Work Options\nProfessional Development ...
# 3  Private Health Insurance\nComprehensive Global...
# 4  Health Insurance\nDental Insurance\n401(k) Ret...
#
#                                           industries company_id
# 0                 Enterprise Software, Cybersecurity          2
# 1                    Consulting, Enterprise Software          3
# 2           Quantitative Finance, Financial Services          5
# 3                    Consulting, Enterprise Software         57
# 4  VR & AR, Consumer Software, Fintech, Consumer ...         59
#
# [5 rows x 23 columns]

# %%
columns_to_check = ['description', 'overview', 'believer_points', 
                    'critic_points', 'what_makes_unique']

# %%
flag_cols = [
    'description_red_flags_with_weights',
    'overview_red_flags_with_weights',
    'believer_points_red_flags_with_weights',
    'critic_points_red_flags_with_weights',
    'what_makes_unique_red_flags_with_weights'
]

# %%
def compute_red_flag_score(row):
    total = 0
    for col in flag_cols:
        flags = row.get(col, {})
        if isinstance(flags, dict):
            total += sum(flags.values())
    return total

# %%
for col in columns_to_check:
    df_companies[f'{col}_red_flags_with_weights'] = (df_companies[col].apply(detect_red_flags_and_weights)
)

# %%
df_companies['red_flag_score'] = df_companies.apply(compute_red_flag_score, axis=1)

# %%
pd.set_option('display.max_colwidth', None)
df_companies[['company_name', 'description_red_flags_with_weights']].head()
# Out:
#                company_name  \
# 0                 1Password
# 1                   7shifts
# 2  Acadian Asset Management
# 3                    Appian
# 4                     Apple
#
#                                                                                                   description_red_flags_with_weights
# 0                                                                                {'password manager': 1, 'secure digital wallet': 1}
# 1                                                                            {'labor compliance easy': 3, 'Get started for free': 2}
# 2                                                                                                                                 {}
# 3                                                                                                         {'lack of specificity': 2}
# 4  {'American multinational technology company': 1, 'specializes in consumer electronics, computer software and online services': 2}

# %%
cols_to_show = [
    'normalized_slug',
    'company_name',
    'overview_red_flags',
    'believer_points_red_flags',
    'critic_points_red_flags',
    'what_makes_unique_red_flags',
    'description_red_flags_with_weights',
    'overview_red_flags_with_weights',
    'believer_points_red_flags_with_weights',
    'critic_points_red_flags_with_weights',
    'what_makes_unique_red_flags_with_weights',
    'red_flag_score'
]

# %%
top_red_flags = (
    df_companies
      .sort_values('red_flag_score', ascending=False)
      [cols_to_show]
)

top_red_flags.head()
# Out:
#           normalized_slug              company_name overview_red_flags  \
# 0               1password                 1Password                 []
# 4                   apple                     Apple                 []
# 2  acadianassetmanagement  Acadian Asset Management                 []
# 5                applovin                  AppLovin                 []
# 3                  appian                    Appian                 []
#
#   believer_points_red_flags  \
# 0                        []
# 4                        []
# 2                        []
# 5                        []
# 3                        []
#
#                                                                                     critic_points_red_flags  \
# 0                                             [prici, g pressure, security vul, erabilities, data breaches]
# 4                         [R&D costs, high risk i, vestme, t, geopolitical risks, supply chai, challe, ges]
# 2           [Competitio, from Two Sigma, Regulatory scruti, y, Market volatility, Geopolitical te, sio, s.]
# 5                     [lawsuits, securities fraud, layoffs, leadership cha, ges, i, ter, al restructuri, g]
# 3  [legal ruli, gs, fi, a, cial stability, strategic shifts, clie, t trust, public sector i, efficie, cies]
#
#   what_makes_unique_red_flags  \
# 0                          []
# 4                          []
# 2                          []
# 5                          []
# 3                          []
#
#                                                                        description_red_flags_with_weights  \
# 0  {'password manager': 1, 'remembers all your passwords for you': 3, 'keep account information safe': 2}
# 4                                                        {'American multinational technology company': 1}
# 2                                                                                                      {}
# 5                                                                           {'grow the app ecosystem': 2}
# 3                                                                                             {'None': 1}
#
#                                                                                                                                                                                     overview_red_flags_with_weights  \
# 0                                                                                            {'subscription model': 2, 'seamless employee provisioning': 3, 'enhances security without disrupting productivity': 4}
# 4                                                                                                                                                                     {'trade-in program': 3, 'device upgrades': 2}
# 2  {'focuses on equities and various asset classes in both developed and emerging markets': 2, 'revenue through performance fees linked to investment success': 3, 'emphasizes corporate social responsibility': 1}
# 5                                                                                                                                                                                                                {}
# 3                                                                                                                                                                                            {'H1B Sponsorship': 5}
#
#                                                                                      believer_points_red_flags_with_weights  \
# 0                                                      {'acquisition of Trelica': 3, 'regulatory focus on data privacy': 4}
# 4                                                  {'development could capture market share': 3, 'sustainability goals': 1}
# 2                                                                                         {'Emerging markets expansion': 3}
# 5                                                          {'privacy-compliant advertising': 4, 'transparent ad models': 3}
# 3  {'Growing demand for low-code platforms': 1, 'Partnerships in specialized industries': 1, 'Favorable legal outcomes': 1}
#
#                                                                                                                                                                                                                     critic_points_red_flags_with_weights  \
# 0                                                                                                                                                                                 {'lower prices': 3, 'security vulnerabilities': 4, 'data breaches': 5}
# 4                                                                                                                                                {'high R&D costs without guaranteed success': 4, 'geopolitical risks': 5, 'supply chain challenges': 3}
# 2  {'Competition from firms like Two Sigma may erode Acadian's market share': 3, 'Regulatory scrutiny on quantitative trading could impact Acadian's operations': 4, 'Market volatility from geopolitical tensions may affect Acadian's performance': 2}
# 5                                                                                                                  {'allegedly violating app store rules': 4, 'class action lawsuits alleging securities fraud': 5, 'layoffs and leadership changes': 3}
# 3                                                                                                                                                                   {'Unfavorable legal rulings': 4, 'New CFO': 2, 'UK public sector inefficiencies': 3}
#
#                               what_makes_unique_red_flags_with_weights  \
# 0                                            {'subscription model': 1}
# 4  {'enhances customer loyalty': 2, 'incentivizes device upgrades': 3}
# 2    {'proprietary database': 3, 'sophisticated analytical models': 4}
# 5                        {'user acquisition': 2, 'ad monetization': 2}
# 3                                      {'subscription-based model': 4}
#
#    red_flag_score
# 0              35
# 4              27
# 2              25
# 5              25
# 3              22

# %%
top_red_flags.to_csv('top_red_flags.csv', index=False)
