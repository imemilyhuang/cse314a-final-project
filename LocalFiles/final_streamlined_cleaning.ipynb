# %%
import pandas as pd
import re
import numpy as np

# %%
df_levels = pd.read_csv("../FinalizedCSVs/companies.csv")
df_internships = pd.read_csv("../FinalizedCSVs/internships.csv")
df_simplify = pd.read_csv("../FinalizedCSVs/simplify_companies.csv")

# %%
degree_pattern = re.compile(r'^(Undergrad|Masters|PhD)\b', flags=re.IGNORECASE)

# %%
def split_perks(cell):
    if pd.isna(cell):
        return pd.Series({'degree_requirement': np.nan, 'perks_clean': np.nan})
    text = str(cell).strip().strip('"')

    parts = re.split(r'(?:\\n|\n)', text, maxsplit=1)

    if len(parts) > 1 and degree_pattern.match(parts[0]):
        return pd.Series({
            'degree_requirement': parts[0].strip(),
            'perks_clean':        parts[1].strip()
        })

    if degree_pattern.match(text) and len(parts) == 1:
        return pd.Series({
            'degree_requirement': text.strip(),
            'perks_clean':        ''
        })

    return pd.Series({
        'degree_requirement': np.nan,
        'perks_clean':        text
    })

# %%
def normalize_slug(slug):
    if pd.isna(slug):
        return ""
    return re.sub(r"[^a-z0-9]", "", slug.lower())

# %%
df_levels['normalized_slug'] = df_levels['company_slug'].apply(normalize_slug)
df_internships['normalized_slug'] = df_internships['company_slug'].apply(normalize_slug)
df_simplify['normalized_slug'] = df_simplify['company_simplify_slug'].apply(normalize_slug)

# %%
df_internships[['degree_requirement','perks_clean']] = \
    df_internships['perks'].apply(split_perks)

# %%
companies = pd.merge(df_levels, df_simplify, on='normalized_slug', how='outer', suffixes=('_levels', '_simplify'))

companies_table = companies[[
    'normalized_slug',
    'company_name', 'description', 'overview',
    'website', 'twitter', 'linkedin',
    'year_founded', 'founded_year',
    'num_employees', 'company_size',
    'headquarters', 'simplify_headquarters',
    'company_stage', 'total_funding',
    'simplify_url', 'simplify_take',
    'believer_points', 'critic_points', 'what_makes_unique',
    'benefits', 'industries'
]].copy()

companies_table = companies_table.drop_duplicates(subset=['normalized_slug']).reset_index(drop=True)
companies_table['company_id'] = companies_table.index + 1

# %%
internships_table = pd.merge(df_internships, companies_table[['normalized_slug', 'company_id']], on='normalized_slug', how='left')

internships_table = internships_table[[
    'company_id', 'title', 'location', 'hourly_rate', 'monthly_pay', 'degree_requirement', 'perks_clean', 'apply_link'
]].drop_duplicates().reset_index(drop=True)

internships_table['internship_id'] = internships_table.index + 1

# %%
industry_set = set()
company_industries = []

for idx, row in companies.iterrows():
    raw = row.get('industries', '')
    if pd.notna(raw):
        inds = [i.strip() for i in raw.split(',')]
        for ind in inds:
            industry_set.add(ind)
            company_industries.append((row['normalized_slug'], ind))

industries_table = pd.DataFrame({'name': sorted(industry_set)})
industries_table['industry_id'] = industries_table.index + 1

company_industries_table = pd.DataFrame(company_industries, columns=['normalized_slug', 'industry_name'])
company_industries_table = company_industries_table.merge(
    companies_table[['normalized_slug', 'company_id']], on='normalized_slug', how='left'
).merge(
    industries_table, left_on='industry_name', right_on='name', how='left'
)[['company_id', 'industry_id']]

# %%
location_set = set()
internship_locations = []

for idx, row in internships_table.iterrows():
    loc = row['location']
    if pd.notna(loc) and isinstance(loc, str):

        loc_clean = loc.split(" - ")[0].strip()
        parts = loc_clean.split(", ")
        if len(parts) == 2:
            city, state = parts
            country = "United States"
        elif len(parts) == 3:
            city, state, country = parts
        else:
            continue
        location_set.add((city, state, country))
        internship_locations.append((row['internship_id'], city, state, country))

locations_table = pd.DataFrame(list(location_set), columns=['city', 'state', 'country'])
locations_table['location_id'] = locations_table.index + 1

internship_locations_table = pd.DataFrame(internship_locations, columns=['internship_id', 'city', 'state', 'country'])
internship_locations_table = internship_locations_table.merge(
    locations_table, on=['city', 'state', 'country'], how='left'
)[['internship_id', 'location_id']]
internship_locations_table['is_remote'] = False

# %%
companies_table.head(20)
# Out:
#            normalized_slug              company_name  \
# 0                    1fort                     1Fort
# 1                1password                 1Password
# 2                  7shifts                   7shifts
# 3              8451degrees             84.51 Degrees
# 4   acadianassetmanagement  Acadian Asset Management
# 5           acarasolutions           Acara Solutions
# 6                accenture                 Accenture
# 7                   actian                    Actian
# 8           activecampaign            ActiveCampaign
# 9               activision                Activision
# 10                 adatech                  Ada Tech
# 11                 addepar                   Addepar
# 12                adimpact                  AdImpact
# 13                   adobe                     Adobe
# 14                     adp                       ADP
# 15                     adt                       ADT
# 16               affinipay                 AffiniPay
# 17                  affirm                    Affirm
# 18          agfinvestments           AGF Investments
# 19                   agoda                     Agoda
#
#                                           description  \
# 0                                                 NaN
# 1   A password manager, digital vault, form filler...
# 2   Restaurant Employee Scheduling Software. Make ...
# 3                                                 NaN
# 4                                                 NaN
# 5   Acara Solutions is a leading provider of recru...
# 6   Accenture plc, stylised as accenture, is an Ir...
# 7                                                 NaN
# 8   ActiveCampaign's category-defining Customer Ex...
# 9   Activision Publishing, Inc. is an American vid...
# 10                                                NaN
# 11  Addepar is a wealth management platform that s...
# 12                                                NaN
# 13  Adobe Inc., known until October 3, 2018 as Ado...
# 14  ADP offers industry-leading online payroll and...
# 15  ADT Inc. is a security and automation company ...
# 16  AffiniPay is a financial technology company, c...
# 17  With Affirm, you can pay over time at your fav...
# 18                                                NaN
# 19  Incredible deals on accommodation in beautiful...
#
#                                              overview  \
# 0                                                 NaN
# 1   1Password provides a password management and s...
# 2   7shifts is a workforce management platform tai...
# 3                                                 NaN
# 4   Acadian Asset Management specializes in invest...
# 5                                                 NaN
# 6                                                 NaN
# 7   Actian transforms large volumes of data into a...
# 8   ActiveCampaign provides a platform designed to...
# 9                                                 NaN
# 10                                                NaN
# 11  Addepar provides investment management softwar...
# 12                                                NaN
# 13  Adobe provides a range of software solutions f...
# 14                                                NaN
# 15                                                NaN
# 16  AffiniPay provides payment solutions specifica...
# 17      Company Historically Provides H1B Sponsorship
# 18                                                NaN
# 19                                                NaN
#
#                                               website  \
# 0                                                 NaN
# 1   https://1password.com/?ref=levels.fyi&utm_sour...
# 2   https://www.7shifts.com/?ref=levels.fyi&utm_so...
# 3                                                 NaN
# 4                                                 NaN
# 5   https://www.acarasolutions.com/?ref=levels.fyi...
# 6   https://www.accenture.com/?ref=levels.fyi&utm_...
# 7                                                 NaN
# 8   https://www.activecampaign.com/?ref=levels.fyi...
# 9   https://www.activision.com/?ref=levels.fyi&utm...
# 10                                                NaN
# 11  https://www.addepar.com/?ref=levels.fyi&utm_so...
# 12                                                NaN
# 13  https://www.adobe.com/?ref=levels.fyi&utm_sour...
# 14  https://www.adp.com/?ref=levels.fyi&utm_source...
# 15  http://www.adt.com/?ref=levels.fyi&utm_source=...
# 16  https://affinipay.com/?ref=levels.fyi&utm_sour...
# 17  https://www.affirm.com/?ref=levels.fyi&utm_sou...
# 18                                                NaN
# 19  https://www.agoda.com/?ref=levels.fyi&utm_sour...
#
#                                 twitter  \
# 0                                   NaN
# 1         https://twitter.com/1Password
# 2           https://twitter.com/7shifts
# 3                                   NaN
# 4                                   NaN
# 5   https://twitter.com/Acara_Solutions
# 6         https://twitter.com/Accenture
# 7                                   NaN
# 8    https://twitter.com/ActiveCampaign
# 9        https://twitter.com/Activision
# 10                                  NaN
# 11          https://twitter.com/Addepar
# 12                                  NaN
# 13            https://twitter.com/Adobe
# 14              https://twitter.com/ADP
# 15              https://twitter.com/ADT
# 16        https://twitter.com/affinipay
# 17           https://twitter.com/Affirm
# 18                                  NaN
# 19            https://twitter.com/agoda
#
#                                              linkedin  year_founded  \
# 0                                                 NaN           NaN
# 1          https://www.linkedin.com/company/1password        2005.0
# 2            https://www.linkedin.com/company/7shifts        2014.0
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# 5     https://www.linkedin.com/company/acarasolutions        1957.0
# 6     https://www.linkedin.com/company/accentureindia        1989.0
# 7                                                 NaN           NaN
# 8   https://www.linkedin.com/company/activecampaig...        2003.0
# 9         https://www.linkedin.com/company/activision        1979.0
# 10                                                NaN           NaN
# 11           https://www.linkedin.com/company/addepar        2009.0
# 12                                                NaN           NaN
# 13             https://www.linkedin.com/company/adobe        1982.0
# 14               https://www.linkedin.com/company/adp        1949.0
# 15               https://www.linkedin.com/company/adt        1874.0
# 16         https://www.linkedin.com/company/affinipay        2005.0
# 17            https://www.linkedin.com/company/affirm        2012.0
# 18                                                NaN           NaN
# 19             https://www.linkedin.com/company/agoda        2005.0
#
#     founded_year num_employees  ...                    company_stage  \
# 0            NaN           NaN  ...                              NaN
# 1         2005.0           420  ...                         Series C
# 2         2014.0           290  ...                         Series C
# 3            NaN           NaN  ...                              NaN
# 4         1986.0           NaN  ...                              NaN
# 5            NaN           480  ...                              NaN
# 6            NaN       492,185  ...                              NaN
# 7         2005.0           NaN  ...                         Series E
# 8         2003.0           960  ...                         Series C
# 9            NaN         9,250  ...                              NaN
# 10           NaN           NaN  ...                              NaN
# 11        2009.0           540  ...                    Late Stage VC
# 12           NaN           NaN  ...                              NaN
# 13        1994.0        21,250  ...                              IPO
# 14           NaN        65,100  ...                              NaN
# 15           NaN        22,000  ...                              NaN
# 16        2005.0           210  ...  Growth Equity (Venture Capital)
# 17        2012.0         2,000  ...                              IPO
# 18           NaN           NaN  ...                              NaN
# 19           NaN         4,500  ...                              NaN
#
#    total_funding                                      simplify_url  \
# 0            NaN                     https://simplify.jobs/c/1Fort
# 1          $920M                 https://simplify.jobs/c/1Password
# 2          $131M                   https://simplify.jobs/c/7shifts
# 3            NaN             https://simplify.jobs/c/84.51-Degrees
# 4            NaN  https://simplify.jobs/c/Acadian-Asset-Management
# 5            NaN           https://simplify.jobs/c/Acara-Solutions
# 6            NaN                 https://simplify.jobs/c/Accenture
# 7         $84.5M                    https://simplify.jobs/c/Actian
# 8          $360M            https://simplify.jobs/c/ActiveCampaign
# 9            NaN                https://simplify.jobs/c/Activision
# 10           NaN                  https://simplify.jobs/c/Ada-Tech
# 11       $672.8M                   https://simplify.jobs/c/Addepar
# 12           NaN                  https://simplify.jobs/c/AdImpact
# 13       $668.9M                     https://simplify.jobs/c/Adobe
# 14           NaN                       https://simplify.jobs/c/ADP
# 15           NaN                       https://simplify.jobs/c/ADT
# 16           NaN                 https://simplify.jobs/c/AffiniPay
# 17        $4720M                    https://simplify.jobs/c/Affirm
# 18           NaN           https://simplify.jobs/c/AGF-Investments
# 19           NaN                     https://simplify.jobs/c/Agoda
#
#                                         simplify_take  \
# 0                                                 NaN
# 1   What believers are saying Growing demand for s...
# 2   What believers are saying 7shifts ranked 382 o...
# 3                                                 NaN
# 4   What believers are saying Increased interest i...
# 5                                                 NaN
# 6                                                 NaN
# 7   What believers are saying Growing demand for h...
# 8   What believers are saying Acquisition of Hilos...
# 9                                                 NaN
# 10                                                NaN
# 11  What believers are saying Addepar's partnershi...
# 12                                                NaN
# 13  What believers are saying Growing demand for A...
# 14                                                NaN
# 15                                                NaN
# 16  What believers are saying AffiniPay's AI-power...
# 17  What believers are saying Affirm's partnership...
# 18                                                NaN
# 19                                                NaN
#
#                                       believer_points  \
# 0                                                 NaN
# 1   Growing demand for secure access solutions due...
# 2   7shifts ranked 382 on the 2024 Deloitte Techno...
# 3                                                 NaN
# 4   Increased interest in ESG investing aligns wit...
# 5                                                 NaN
# 6                                                 NaN
# 7   Growing demand for hybrid cloud solutions alig...
# 8   Acquisition of Hilos expands WhatsApp automati...
# 9                                                 NaN
# 10                                                NaN
# 11  Addepar's partnership with Corient enhances it...
# 12                                                NaN
# 13  Growing demand for AI-driven creative tools bo...
# 14                                                NaN
# 15                                                NaN
# 16  AffiniPay's AI-powered features enhance paymen...
# 17  Affirm's partnership with Shopify expands its ...
# 18                                                NaN
# 19                                                NaN
#
#                                         critic_points  \
# 0                                                 NaN
# 1   Emerging competitors offer similar features at...
# 2   19% staff reduction may impact 7shifts' servic...
# 3                                                 NaN
# 4   Competition from firms like Two Sigma may erod...
# 5                                                 NaN
# 6                                                 NaN
# 7   Decentralized data management challenges Actia...
# 8   Emerging AI-driven platforms may erode ActiveC...
# 9                                                 NaN
# 10                                                NaN
# 11  Competition from fintech startups may erode Ad...
# 12                                                NaN
# 13  Generative AI platforms like Writer pose a thr...
# 14                                                NaN
# 15                                                NaN
# 16  AffiniPay is up for sale, potentially leading ...
# 17  Increased competition from BNPL providers like...
# 18                                                NaN
# 19                                                NaN
#
#                                     what_makes_unique  \
# 0                                                 NaN
# 1   1Password integrates seamlessly with IAM syste...
# 2   7shifts offers a comprehensive platform tailor...
# 3                                                 NaN
# 4   Acadian uses sophisticated analytical models f...
# 5                                                 NaN
# 6                                                 NaN
# 7   Actian offers a hybrid cloud data warehouse, A...
# 8   ActiveCampaign offers 800+ pre-built automatio...
# 9                                                 NaN
# 10                                                NaN
# 11  Addepar integrates with over 100 partners, off...
# 12                                                NaN
# 13  Adobe's Creative Cloud offers a comprehensive ...
# 14                                                NaN
# 15                                                NaN
# 16  AffiniPay specializes in payment solutions for...
# 17  Affirm offers transparent payment plans with n...
# 18                                                NaN
# 19                                                NaN
#
#                                              benefits  \
# 0                                                 NaN
# 1   👶 Maternity and parental leave top up programs...
# 2   Health Insurance\nCompany Equity\nFlexible Wor...
# 3                                                 NaN
# 4   Hybrid Work Options\nProfessional Development ...
# 5                                                 NaN
# 6                                                 NaN
# 7   Health Insurance\nParental Leave\nPaid Vacatio...
# 8   Health Insurance\nUnlimited Paid Time Off\n401...
# 9                                                 NaN
# 10                                                NaN
# 11  Equity: Stretch the idea of ownership beyond y...
# 12                                                NaN
# 13               Company Equity\n401(k) Company Match
# 14                                                NaN
# 15                                                NaN
# 16                                Remote Work Options
# 17  Spending wallets: Access tech, food, lifestyle...
# 18                                                NaN
# 19                                                NaN
#
#                                         industries company_id
# 0                                              NaN          1
# 1               Enterprise Software, Cybersecurity          2
# 2                  Consulting, Enterprise Software          3
# 3                                              NaN          4
# 4         Quantitative Finance, Financial Services          5
# 5                                              NaN          6
# 6                                              NaN          7
# 7            Data & Analytics, Enterprise Software          8
# 8            Data & Analytics, Enterprise Software          9
# 9                                              NaN         10
# 10                                             NaN         11
# 11                     Fintech, Financial Services         12
# 12                                             NaN         13
# 13  Consumer Software, Enterprise Software, Design         14
# 14                                             NaN         15
# 15                                             NaN         16
# 16                     Fintech, Financial Services         17
# 17                     Fintech, Financial Services         18
# 18                                             NaN         19
# 19                                             NaN         20
#
# [20 rows x 23 columns]

# %%
df_internships.head()
# Out:
#           company_slug         company_name                      title  \
# 0        radix-trading        Radix Trading  Quantitative Technologist
# 1  arrowstreet-capital  Arrowstreet Capital    Quantitative Researcher
# 2           five-rings           Five Rings    Quantitative Researcher
# 3                  sig                  SIG        Quantitative Trader
# 4             d-e-shaw            D.E. Shaw                        NaN
#
#                              location hourly_rate monthly_pay  \
# 0        Chicago, IL -  Summer / 2025    $166.67     $28,890
# 1         Boston, MA -  Summer / 2025    $152.88     $26,499
# 2  New York City, NY -  Summer / 2025    $143.75     $24,917
# 3    Bala Cynwyd, PA -  Summer / 2025    $137.50     $23,833
# 4  New York City, NY -  Summer / 2025    $126.92     $22,000
#
#                                                perks  \
# 0           Corporate housing, $25,000 sign-on bonus
# 1  Undergrad (Junior)\n$10,000 Housing, company p...
# 2                   Corporate housing, Sign-on bonus
# 3  Undergrad (Junior)\nCorporate housing, $20,000...
# 4  Undergrad (Senior)\n$10,000 Housing, company p...
#
#                                           apply_link     normalized_slug  \
# 0  https://boards.greenhouse.io/radixuniversity/j...        radixtrading
# 1                                                NaN  arrowstreetcapital
# 2  https://job-boards.greenhouse.io/fiveringsllc/...           fiverings
# 3                                                NaN                 sig
# 4                                                NaN              deshaw
#
#    degree_requirement                                        perks_clean
# 0                 NaN           Corporate housing, $25,000 sign-on bonus
# 1  Undergrad (Junior)  $10,000 Housing, company provided transportati...
# 2                 NaN                   Corporate housing, Sign-on bonus
# 3  Undergrad (Junior)                 Corporate housing, $20,000 sign-on
# 4  Undergrad (Senior)  $10,000 Housing, company provided relocation, ...

# %%
companies_table.to_csv("export_companies.csv", index=False)
internships_table.to_csv("export_internships.csv", index=False)
locations_table.to_csv("export_locations.csv", index=False)
internship_locations_table.to_csv("export_internship_locations.csv", index=False)
industries_table.to_csv("export_industries.csv", index=False)
company_industries_table.to_csv("export_company_industries.csv", index=False)
